# %% [markdown]
# # Resumen del Proceso de Extracción de IDs para Datos de AcousticBrainz
#
# En este notebook, documentamos el proceso para extraer datos de la API de MusicBrainz y enriquecer nuestro dataset con `recording_id` de las canciones para después sacar todas los valores porcentuales de las características de cada canción. A continuación, se describe el flujo de trabajo:
#
# 1. **📚 Importación de Librerías**:
#     - Importamos las librerías necesarias como `numpy`, `pandas`, `requests`, `time` y `os`.
#
# 2. **📂 Carga y Preparación del Dataset**:
#     - Cargamos el dataset inicial desde un archivo CSV.
#     - Filtramos las columnas necesarias (`song_name` y `artist_name`) y guardamos un archivo simplificado.
#
# 3. **🔧 Definición de Funciones**:
#     - Definimos la función `get_recording_id(df)` que se encarga de obtener el `recording_id` de cada canción utilizando la API de MusicBrainz.
#     - La función maneja solicitudes HTTP, procesa las respuestas y guarda los resultados en archivos temporales (`nuevos_ids_encontrados.csv.temp` y `ids_no_encontrados.csv.temp`).
#
# 4. **🗂️ Inicialización del Dataset**:
#     - Cargamos el dataset a procesar y nos aseguramos de que la columna `recording_id` esté presente.
#
# 5. **🚀 Ejecución del Proceso de Extracción**:
#     - Ejecutamos la función `get_recording_id(df)` para obtener los `recording_id` y guardarlos en los archivos correspondientes.
#
# 6. **📊 Resultados**:
#     - Los resultados se guardan en dos archivos:
#       - `nuevos_ids_encontrados.csv.temp`: Contiene las canciones para las cuales se encontró un `recording_id`.
#       - `ids_no_encontrados.csv.temp`: Contiene las canciones para las cuales no se encontró un `recording_id`.
#
# 7. **🔍 Consideraciones Adicionales**:
#     - Si se vuelve a ejecutar la función, los nuevos datos se añaden al final de los archivos existentes para evitar duplicados.
#     - Se recomienda eliminar los datos ya procesados de los archivos temporales antes de una nueva ejecución para optimizar el tiempo de procesamiento.
#
# Este flujo de trabajo nos permite enriquecer nuestro dataset con información adicional de MusicBrainz de manera eficiente y organizada.

# %%
# Importación de Librerías
import numpy as np
import pandas as pd
import requests # para realizar solicitudes HTTP y obtener datos de una API externa, en este caso Brainz
import time
import os # para interactuar con el sistema de archivos, permitiendo la lectura y escritura de archivos necesarios para el análisis

# %% [markdown]
# ##### ELEGIR LA PARTE DEL DATA SET CON EL QUE EMPEZAMOS
#
# Nos hemos dividido los datos para ir sacándolos poco a poco ya que el dataset es muy grande y solo hemos podido procesar una pequeña parte de él.
# A futuro se puede ver como podemos seguir extrayendo datos

# %%
import pandas as pd
import os

# Rutas de los archivos
final_output_path = "../data/split_datasets/genius_songs_batch_1.csv"
simple_output_path = "../data/raw/1_toprocess.csv"

# Cargar el archivo final existente
if os.path.exists(final_output_path):
    final_df = pd.read_csv(final_output_path)
    # Filtrar solo las columnas necesarias
    simple_df = final_df[['song_name', 'artist_name']]
    
    # Guardar el resultado en un nuevo archivo
    simple_df.to_csv(simple_output_path, index=False)
    print(f"Archivo simplificado guardado en: {simple_output_path}")
    print(simple_df.head(), simple_df.shape)
else:
    print(f"El archivo final {final_output_path} no existe. Por favor, verifica la ruta.")
# Out:
# Archivo simplificado guardado en: C:\Users\solan\Downloads\get_data_from_songs\data\raw\1_toprocess.csv
#                      song_name                     artist_name
# 0               gasolina remix                    daddy yankee
# 1                        rompe                    daddy yankee
# 2  we no speak americano remix                         pitbull
# 3           suenos en realidad                        ozomatli
# 4              triste me pongo  califas (mr. lil one & shisty) (10000, 2)

# %% [markdown]
# # Ejemplo de uso de la función para obtener nuevos recording_ids
#
# `df = pd.read_csv(ruta_al_dataset_a_procesar.csv)`
#
# `get_recording_id(df)`

# %% [markdown]
# # Función para obtener nuevos recording_ids

# %%
def get_recording_id(df):
    # Función para obtener el recording_id desde la API de MusicBrainz
    def get_recording_id(title, artist):
        query = f'recording:"{title}" AND artist:"{artist}"'
        url = f"https://musicbrainz.org/ws/2/recording/?query={query}&fmt=json"

        try:
            response = requests.get(url, timeout=10)  # Agregar timeout para evitar bloqueos indefinidos
            if response.status_code == 200:
                data = response.json()
                if "recordings" in data and len(data["recordings"]) > 0:
                    return data["recordings"][0]["id"]
            return None
        except requests.exceptions.RequestException as e:
            print(f"Error on search '{title}' - '{artist}': {e}")
            return None

    # Rutas de los archivos de salida
    found_file = r"C:\Users\solan\Downloads\get_data_from_songs\data\raw\1_nuevos_ids_encontrados.csv.temp"
    not_found_file = r"C:\Users\solan\Downloads\get_data_from_songs\data\1ids_no_encontrados.csv.temp"

    # Crear los archivos si no existen
    # En caso de que ya existan y tengan registros, en lugar de sobrescribirse, los nuevos se añaden al final
    if not os.path.exists(found_file):
        pd.DataFrame(columns=["artist_name", "song_name", "recording_id"]).to_csv(found_file, index=False)
    if not os.path.exists(not_found_file):
        pd.DataFrame(columns=["artist_name", "song_name"]).to_csv(not_found_file, index=False)

    # Inicializar contadores
    total_requests = 0

    # Procesar el DataFrame
    for index in df.index:
        row = df.loc[index]

        # Saltar filas con un recording_id ya existente y válido
        if pd.notna(row["recording_id"]) and row["recording_id"] != "Not found":
            continue

        total_requests += 1
        print(f"\n[Progress] Request {total_requests}/{len(df)}...")

        # Obtener el recording_id
        recording_id = get_recording_id(row["song_name"], row["artist_name"])

        # Procesar y guardar los resultados por cada request
        # Es un poco más lento pero resulta en menos fallos, por lo que es preferible
        if not recording_id:  # Si no se encuentra el recording_id, se almacenan los datos procesados en un dataset ids_no_encontrados.csv.temp
            print(f"  ⚠️ Not Recording ID found for: {row['song_name']} - {row['artist_name']}")
            not_found_df = pd.DataFrame([{"artist_name": row["artist_name"], "song_name": row["song_name"]}])
            not_found_df.to_csv(not_found_file, mode="a", index=False, header=False)
        else:  # Si se encuentra el recording_id, se almacenan los datos procesados en un dataset nuevos_ids_encontrados.csv.temp
            print(f"  ✅ Recording ID found: {recording_id}")
            found_df = pd.DataFrame([{
                "artist_name": row["artist_name"],
                "song_name": row["song_name"],
                "recording_id": recording_id
            }])
            found_df.to_csv(found_file, mode="a", index=False, header=False)


        # Respetar el límite de velocidad de la API
        time.sleep(1)

    print(f"\nProcessing complete. Results saved in:\n - Found: {found_file}\n - Not Found: {not_found_file}")

# %% [markdown]
# # Obtener nuevos recording_id

# %%
df = pd.read_csv(r'C:\Users\solan\Downloads\get_data_from_songs\data\raw\1_toprocess.csv')

# Inicializar la columna 'recording_id' si no existe
if 'recording_id' not in df.columns:
    df['recording_id'] = None  # O un valor predeterminado como "Not found"

# %%
get_recording_id(df)
# Out:
# [Progress] Request 1/10000...
#   ✅ Recording ID found: 07e4fa19-44db-415b-bd1a-32d72419b819
#
# [Progress] Request 2/10000...
#   ✅ Recording ID found: 156da9c1-0ccf-4205-b5c5-92d01470867f
#
# [Progress] Request 3/10000...
#   ⚠️ Not Recording ID found for: we no speak americano remix - pitbull
#
# [Progress] Request 4/10000...
#   ✅ Recording ID found: 74475a5e-6773-4dc2-91ac-3cc16793ab03
#
# [Progress] Request 5/10000...
#   ✅ Recording ID found: ef3d1f71-d2fc-4ea4-b69c-d3f6a6d148b7
#
# [Progress] Request 6/10000...
#   ✅ Recording ID found: 72b7c164-91f7-4f1c-aaa3-b104d2e86f9b
#
# [Progress] Request 7/10000...
#   ⚠️ Not Recording ID found for: quieren pleito - crooked stilo
#
# [Progress] Request 8/10000...
#   ✅ Recording ID found: 3227a55b-ae2a-4a05-b602-30c6980ce1d1
#
# [Progress] Request 9/10000...
#   ✅ Recording ID found: a9bb0335-f3f3-41c8-9bfc-e4458016a2ca
#
# [Progress] Request 10/10000...
#   ✅ Recording ID found: 2d18355a-c382-4579-bccc-fb5ebaa3128d
#
# [Progress] Request 11/10000...
#   ✅ Recording ID found: 721ce512-4f5a-4253-b57b-3490bab26c49
#
# [Progress] Request 12/10000...
#   ✅ Recording ID found: 56cf00a4-0f85-4140-b9c1-0570241e61f1
#
# [Progress] Request 13/10000...
#   ⚠️ Not Recording ID found for: 2 aztekas - dyablo
#
# [Progress] Request 14/10000...
#   ✅ Recording ID found: 9fc4ffdb-26ad-4d5b-88ca-768e5e00ddb8
#
# [Progress] Request 15/10000...
#   ✅ Recording ID found: 71fe6868-2a69-42de-b8ae-d8d2689c5008
#
# [Progress] Request 16/10000...
#   ✅ Recording ID found: 3091eb2d-4c98-40cc-bfa8-630761fea0ea
#
# [Progress] Request 17/10000...
#   ✅ Recording ID found: 5ef62512-2425-4e2c-9dcd-384b8334c922
#
# [Progress] Request 18/10000...
#   ✅ Recording ID found: 154693e1-d535-419d-91ec-4d4cc5f65c1a
#
# [Progress] Request 19/10000...
#   ✅ Recording ID found: ef0686d8-fa8a-41ed-88dc-efeb1237a3f7
#
# [Progress] Request 20/10000...
#   ✅ Recording ID found: 3901c8a4-6b2f-4cf2-a17a-ef63723f9f28
#
# [Progress] Request 21/10000...
#   ✅ Recording ID found: b8b6d563-99f7-46b7-876f-6c3a39b02097
#
# [Progress] Request 22/10000...
#   ✅ Recording ID found: f1c68dcb-6448-4767-9ebb-524493f128e4
#
# [Progress] Request 23/10000...
#   ✅ Recording ID found: c958a56e-1ce2-4715-b847-10e5555c67c8
#
# [Progress] Request 24/10000...
#   ✅ Recording ID found: 8b15591b-c81b-459e-a113-dcaa095fa393
#
# [Progress] Request 25/10000...
#   ✅ Recording ID found: 40ed8f2b-4afb-47da-8307-a2950e4a275c
#
# [Progress] Request 26/10000...
#   ⚠️ Not Recording ID found for: esto es para esos p@s - dyablo
#
# [Progress] Request 27/10000...
#   ⚠️ Not Recording ID found for: los katrachos - og kid frost
#
# [Progress] Request 28/10000...
#   ✅ Recording ID found: c235c80f-7d99-46b5-90de-26cb87d6cebc
#
# [Progress] Request 29/10000...
#   ⚠️ Not Recording ID found for: marijuana para mi - los marijuanos
#
# [Progress] Request 30/10000...
#   ⚠️ Not Recording ID found for: masacre de cantantes - mexicano 777
#
# [Progress] Request 31/10000...
#   ✅ Recording ID found: 3ec48524-591e-406b-96fa-337c0d05fbce
#
# [Progress] Request 32/10000...
#   ⚠️ Not Recording ID found for: loco - mr. sancho
#
# [Progress] Request 33/10000...
#   ⚠️ Not Recording ID found for: cuando y donde - mr. shadow
#
# [Progress] Request 34/10000...
#   ✅ Recording ID found: b253929f-c131-464b-8d65-3a49c7d9d672
#
# [Progress] Request 35/10000...
#   ✅ Recording ID found: 907b22f7-eb1c-44df-a5b9-5e2102255671
#
# [Progress] Request 36/10000...
#   ✅ Recording ID found: ec3e4a23-c267-4545-bc62-9fa7bfda2cbc
#
# [Progress] Request 37/10000...
#   ✅ Recording ID found: d34a78fe-9c81-400d-a1f8-0b6aa7665ba3
#
# [Progress] Request 38/10000...
#   ✅ Recording ID found: 288d10f8-b3fb-427a-8514-0c2b0b8be3cd
#
# [Progress] Request 39/10000...
#   ⚠️ Not Recording ID found for: todos vamos a morir - slush the villain
#
# [Progress] Request 40/10000...
#   ✅ Recording ID found: 137dc253-84fc-44d2-bc20-2e79eba03dfa
#
# [Progress] Request 41/10000...
#   ✅ Recording ID found: 9765665c-49da-4031-b0b3-55174ebe622a
#
# [Progress] Request 42/10000...
#   ✅ Recording ID found: 91270aa6-e2c9-4ed6-b821-4e683d8f04df
#
# [Progress] Request 43/10000...
#   ✅ Recording ID found: dd131d26-b785-44c4-8943-f3d5b1547717
#
# [Progress] Request 44/10000...
#   ✅ Recording ID found: 48bfe90d-387d-43ae-8177-3be1ded43474
#
# [Progress] Request 45/10000...
#   ✅ Recording ID found: d8b91133-db52-4c27-80ed-67eb8771a252
#
# [Progress] Request 46/10000...
#   ✅ Recording ID found: 736c37f0-9fa3-4335-b411-dc8ffb6b1f63
#
# [Progress] Request 47/10000...
#   ✅ Recording ID found: cfb48c8a-06ed-4864-b211-4568c36100ea
#
# [Progress] Request 48/10000...
#   ✅ Recording ID found: 8d568c15-74dc-4837-97db-2f5606679756
#
# [Progress] Request 49/10000...
#   ✅ Recording ID found: dfca7ee2-9cb4-40fe-876e-560c44d98c70
#
# [Progress] Request 50/10000...
#   ✅ Recording ID found: 234eec94-ae4c-46e5-9144-d184599ee7f7
#
# [Progress] Request 51/10000...
#   ✅ Recording ID found: 44c734d7-6876-4780-bf17-254a84c534e2
#
# [Progress] Request 52/10000...
#   ✅ Recording ID found: 12419abe-8c7a-4ab8-b412-afdfa7a8e988
#
# [Progress] Request 53/10000...
#   ✅ Recording ID found: 7210b456-d06f-4a61-b16c-d799ab5073e0
#
# [Progress] Request 54/10000...
#   ✅ Recording ID found: 5ffe7ec5-8cd6-4e9a-a631-92e4434b4bb5
#
# [Progress] Request 55/10000...
#   ✅ Recording ID found: c5ef4286-190f-4295-8719-28132e2fa530
#
# [Progress] Request 56/10000...
#   ✅ Recording ID found: 4f51398a-a702-4536-8247-892a6ea6c0e1
#
# [Progress] Request 57/10000...
#   ✅ Recording ID found: a3a42682-e3a0-4c91-ad7f-943da10d9c11
#
# [Progress] Request 58/10000...
#   ⚠️ Not Recording ID found for: avellaneda blues - manal (band)
#
# [Progress] Request 59/10000...
#   ⚠️ Not Recording ID found for: tosting light remix - nikolodian
#
# [Progress] Request 60/10000...
#   ✅ Recording ID found: 677854f3-e8cc-4f84-8be4-768fa443a688
#
# [Progress] Request 61/10000...
#   ⚠️ Not Recording ID found for: loco in el coco - cypress hill
#
# [Progress] Request 62/10000...
#   ✅ Recording ID found: a275466e-9836-4174-a426-5f03bad0e133
#
# [Progress] Request 63/10000...
#   ⚠️ Not Recording ID found for: petare barrio de pakistán - el prieto
#
# [Progress] Request 64/10000...
#   ⚠️ Not Recording ID found for: halo - xavi mata
#
# [Progress] Request 65/10000...
#   ✅ Recording ID found: e3ca24f1-2a52-4024-8d33-78512f194510
#
# [Progress] Request 66/10000...
#   ⚠️ Not Recording ID found for: inconsciente - elley
#
# [Progress] Request 67/10000...
#   ✅ Recording ID found: 6d3c452a-37eb-424a-954b-3bf500d401d3
#
# [Progress] Request 68/10000...
#   ⚠️ Not Recording ID found for: sólo me queda decirte adiós - elley
#
# [Progress] Request 69/10000...
#   ⚠️ Not Recording ID found for: infiel a ti - elley
#
# [Progress] Request 70/10000...
#   ⚠️ Not Recording ID found for: glamour - pandesousa
#
# [Progress] Request 71/10000...
#   ✅ Recording ID found: 7118bf81-fbd2-4884-aa04-d4b5678a18c8
#
# [Progress] Request 72/10000...
#   ✅ Recording ID found: 05f5aa67-5b83-4826-898b-53cf39d76326
#
# [Progress] Request 73/10000...
#   ✅ Recording ID found: 8cf71ece-8a91-4d08-bef3-69c9f0d0ed58
#
# [Progress] Request 74/10000...
#   ⚠️ Not Recording ID found for: tiro al piso - mc/ dc
#
# [Progress] Request 75/10000...
#   ⚠️ Not Recording ID found for: un motivo - caballeros del plan g
#
# [Progress] Request 76/10000...
#   ✅ Recording ID found: b6c11ebd-2337-48e3-8da8-50a1c7588e3b
#
# [Progress] Request 77/10000...
#   ✅ Recording ID found: 39949d6c-ea1f-435c-b911-adcb0ce0e339
#
# [Progress] Request 78/10000...
#   ✅ Recording ID found: 1f7fb576-5772-43b6-bb33-5fc324bd9580
#
# [Progress] Request 79/10000...
#   ✅ Recording ID found: f9567b15-a8dd-4838-850f-6ea2489566a1
#
# [Progress] Request 80/10000...
#   ✅ Recording ID found: 7155ce0c-4485-4304-8052-c41206a1837b
#
# [Progress] Request 81/10000...
#   ⚠️ Not Recording ID found for: el sistema - ty (genius)
#
# [Progress] Request 82/10000...
#   ⚠️ Not Recording ID found for: rapeandote al oido solos vos y yo - ale! pluz
#
# [Progress] Request 83/10000...
#   ⚠️ Not Recording ID found for: mi propio estilo - 4ablillo
#
# [Progress] Request 84/10000...
#   ⚠️ Not Recording ID found for: dale pal piso - watussi
#
# [Progress] Request 85/10000...
#   ✅ Recording ID found: ca282659-c699-4a8b-affe-fb4bbc717c45
#
# [Progress] Request 86/10000...
#   ✅ Recording ID found: 6bc369c3-e5ea-472f-9aa2-512c09f46f2a
#
# [Progress] Request 87/10000...
#   ✅ Recording ID found: a11df4dc-92c0-4d3f-b482-6a8845ea1805
#
# [Progress] Request 88/10000...
#   ⚠️ Not Recording ID found for: amuleto - eptos uno
#
# [Progress] Request 89/10000...
#   ⚠️ Not Recording ID found for: beef - eric el nio
#
# [Progress] Request 90/10000...
#   ⚠️ Not Recording ID found for: tiempo english translation - bocafloja
#
# [Progress] Request 91/10000...
#   ✅ Recording ID found: 7b453ba3-aef0-471c-8397-ee0d0b8b431c
#
# [Progress] Request 92/10000...
#   ✅ Recording ID found: 6f217edf-67e2-4055-90e3-bf1cd73f5163
#
# [Progress] Request 93/10000...
#   ✅ Recording ID found: 3bdc634b-ff47-4dd9-9a8b-056df2b17853
#
# [Progress] Request 94/10000...
#   ✅ Recording ID found: d517b016-d09d-4615-b669-ed43ff2d9262
#
# [Progress] Request 95/10000...
#   ⚠️ Not Recording ID found for: lapiz en kille - lapiz conciente
#
# [Progress] Request 96/10000...
#   ⚠️ Not Recording ID found for: producto del ghetto - danger man
#
# [Progress] Request 97/10000...
#   ⚠️ Not Recording ID found for: querido fbi - calle 13
#
# [Progress] Request 98/10000...
#   ⚠️ Not Recording ID found for: el mundo - 3-15
#
# [Progress] Request 99/10000...
#   ✅ Recording ID found: 084127a0-d267-4a1b-80be-7c3e1d7faa03
#
# [Progress] Request 100/10000...
#   ✅ Recording ID found: 3c6c9b9a-0e41-4a5e-9903-98298973e08a
#
# [Progress] Request 101/10000...
#   ✅ Recording ID found: 35b59bf0-a4ba-4a18-b85b-0ebc13c5ccd6
#
# [Progress] Request 102/10000...
#   ✅ Recording ID found: 56e96b77-a776-4515-bbb8-40d16b9e2d04
#
# [Progress] Request 103/10000...
#   ✅ Recording ID found: fba3e871-1e41-4b35-ae2e-262c5a2ba8ab
#
# [Progress] Request 104/10000...
#   ✅ Recording ID found: adc5b909-32da-4af4-8ec3-d6a594d7497d
#
# [Progress] Request 105/10000...
#   ⚠️ Not Recording ID found for: ponme to eso pa lante - el chuape
#
# [Progress] Request 106/10000...
#   ✅ Recording ID found: fcfab0e0-435d-4d42-9e1b-4bfe33714206
#
# [Progress] Request 107/10000...
#   ⚠️ Not Recording ID found for: la mafia de tablada - 4ablillo
#
# [Progress] Request 108/10000...
#   ⚠️ Not Recording ID found for: pan y coca helada - ashede
#
# [Progress] Request 109/10000...
#   ✅ Recording ID found: a96d3fd8-c047-4ec6-89bb-aa0662adf5b3
#
# [Progress] Request 110/10000...
#   ⚠️ Not Recording ID found for: la nueva españa - frank t
#
# [Progress] Request 111/10000...
#   ⚠️ Not Recording ID found for: rayos de sol - jos de rico
#
# [Progress] Request 112/10000...
#   ⚠️ Not Recording ID found for: ayer - hordatoj
#
# [Progress] Request 113/10000...
#   ⚠️ Not Recording ID found for: era de verdad - hordatoj
#
# [Progress] Request 114/10000...
#   ✅ Recording ID found: 836d0705-cfa6-433b-b0ae-34a1ec0c063c
#
# [Progress] Request 115/10000...
#   ✅ Recording ID found: 017b4512-5f39-42e5-99ce-344635d06e38
#
# [Progress] Request 116/10000...
#   ✅ Recording ID found: 9d3557c9-2dea-4678-bf74-eac6e2f8b4d1
#
# [Progress] Request 117/10000...
#   ✅ Recording ID found: 49049ff0-9d5d-44b9-a8f9-28b3874df944
#
# [Progress] Request 118/10000...
#   ✅ Recording ID found: a9519f25-1ea5-4b63-8d56-98ae9dd2fac9
#
# [Progress] Request 119/10000...
#   ✅ Recording ID found: 0cb0ad53-ba20-4720-bb2a-96a248a2c550
#
# [Progress] Request 120/10000...
#   ✅ Recording ID found: 4d749f75-fcac-4be2-bf78-a10baf9b83ba
#
# [Progress] Request 121/10000...
#   ✅ Recording ID found: 632161b7-c009-4990-a45d-093fc3c51445
#
# [Progress] Request 122/10000...
#   ⚠️ Not Recording ID found for: sin ti - nancy diaz
#
# [Progress] Request 123/10000...
#   ✅ Recording ID found: b867c201-6e9f-4c0a-b323-e4e1fdd97a9b
#
# [Progress] Request 124/10000...
#   ✅ Recording ID found: 1b28cd63-f29e-462f-81ce-8c174b3890cc
#
# [Progress] Request 125/10000...
#   ✅ Recording ID found: 87166d3b-d867-48ed-9fad-c7ac0914e361
#
# [Progress] Request 126/10000...
#   ✅ Recording ID found: ef65339b-3128-482c-bedc-f933ffadb28b
#
# [Progress] Request 127/10000...
#   ✅ Recording ID found: b0e6a297-2a9a-458d-903a-795b2fd70600
#
# [Progress] Request 128/10000...
#   ✅ Recording ID found: e6b9fb8c-3a46-452c-903d-db4096851e7c
#
# [Progress] Request 129/10000...
#   ✅ Recording ID found: 5f7bf18f-29d7-425c-805f-f8b57c96c52f
#
# [Progress] Request 130/10000...
#   ✅ Recording ID found: 5beada09-d5cc-4d59-976f-e32ca001d614
#
# [Progress] Request 131/10000...
#   ✅ Recording ID found: c078633c-5fbe-468e-982b-b37a793ae49a
#
# [Progress] Request 132/10000...
#   ⚠️ Not Recording ID found for: jeremías 17:5 - canserbero
#
# [Progress] Request 133/10000...
#   ⚠️ Not Recording ID found for: eres - caf tacvba
#
# [Progress] Request 134/10000...
#   ✅ Recording ID found: d668844a-b4c4-46ad-8016-1dd4872edf7f
#
# [Progress] Request 135/10000...
#   ⚠️ Not Recording ID found for: hit me gimme tha power 2 - molotov
#
# [Progress] Request 136/10000...
#   ✅ Recording ID found: 049f47cc-0f1d-48f1-8305-cdf4590ca0fb
#
# [Progress] Request 137/10000...
#   ✅ Recording ID found: 2e3b52d5-861d-49dd-89e6-9c31fe8a6dc7
#
# [Progress] Request 138/10000...
#   ✅ Recording ID found: 3490b3f8-fb88-40a5-be9f-e5002c5f97a5
#
# [Progress] Request 139/10000...
#   ⚠️ Not Recording ID found for: esta noche - 3-15
#
# [Progress] Request 140/10000...
#   ✅ Recording ID found: 17301a61-26b4-4ae8-8f0a-b91fcc4c0226
#
# [Progress] Request 141/10000...
#   ✅ Recording ID found: b68c9065-d5a0-4b7b-95eb-c917329f072a
#
# [Progress] Request 142/10000...
#   ✅ Recording ID found: ddaf7421-2204-4864-82a1-1091ef5c31e0
#
# [Progress] Request 143/10000...
#   ✅ Recording ID found: d78a3647-df81-417c-9e66-d4966905bd68
#
# [Progress] Request 144/10000...
#   ⚠️ Not Recording ID found for: hijo de duerte - locotron
#
# [Progress] Request 145/10000...
#   ⚠️ Not Recording ID found for: impotencia - ashede
#
# [Progress] Request 146/10000...
#   ✅ Recording ID found: 4eb50de1-dc0d-4ff3-93eb-dde5c2434c30
#
# [Progress] Request 147/10000...
#   ⚠️ Not Recording ID found for: mammy test - wow mammy
#
# [Progress] Request 148/10000...
#   ⚠️ Not Recording ID found for: im big - big laing
#
# [Progress] Request 149/10000...
#   ✅ Recording ID found: 6572a965-72db-464f-8f76-8d667b9e680d
#
# [Progress] Request 150/10000...
#   ✅ Recording ID found: 611162b4-7113-41ff-8741-018da7b94490
#
# [Progress] Request 151/10000...
#   ✅ Recording ID found: 61a7fd7c-bcfa-48a6-99ae-9ae679d2ba08
#
# [Progress] Request 152/10000...
#   ⚠️ Not Recording ID found for: el cheroke de la muerte - los originales de san juan
#
# [Progress] Request 153/10000...
#   ⚠️ Not Recording ID found for: el ahogado más hermoso del mundo - gabriel garca mrquez
#
# [Progress] Request 154/10000...
#   ✅ Recording ID found: db28d519-4198-4d51-b2be-b37e4e04af2d
#
# [Progress] Request 155/10000...
#   ⚠️ Not Recording ID found for: fuego soy  exclusive  - nay-b
#
# [Progress] Request 156/10000...
#   ⚠️ Not Recording ID found for: nadie mejor - the most
#
# [Progress] Request 157/10000...
#   ✅ Recording ID found: 9dc39681-caf8-40a2-8822-5608c44dd223
#
# [Progress] Request 158/10000...
#   ✅ Recording ID found: ed390b02-75ab-4580-af34-8a06397b2cdb
#
# [Progress] Request 159/10000...
#   ⚠️ Not Recording ID found for: noche de travesura - hctor el father
#
# [Progress] Request 160/10000...
#   ✅ Recording ID found: c42f4cdf-892e-47a2-9265-8c8f0c2c14c5
#
# [Progress] Request 161/10000...
#   ⚠️ Not Recording ID found for: esperando la cita - marius l.
#
# [Progress] Request 162/10000...
#   ⚠️ Not Recording ID found for: confusión - safio
#
# [Progress] Request 163/10000...
#   ⚠️ Not Recording ID found for: la marea - tof,kinpenman
#
# [Progress] Request 164/10000...
#   ✅ Recording ID found: fdadfcc8-6106-41b5-a0e6-b9d1a8680813
#
# [Progress] Request 165/10000...
#   ✅ Recording ID found: 5104c0a1-dd34-4c34-80e2-34725744aceb
#
# [Progress] Request 166/10000...
#   ✅ Recording ID found: 79430afc-9c8e-4fc5-86e8-358d44657787
#
# [Progress] Request 167/10000...
#   ✅ Recording ID found: 95f4c528-243f-4f09-874b-7d9b3cb5a246
#
# [Progress] Request 168/10000...
#   ✅ Recording ID found: edc205c6-12be-4958-abf7-b079b6e0afbe
#
# [Progress] Request 169/10000...
#   ⚠️ Not Recording ID found for: 101 rap - community
#
# [Progress] Request 170/10000...
#   ✅ Recording ID found: f3ac70de-cc9c-45fc-b47f-dafbd9287586
#
# [Progress] Request 171/10000...
#   ✅ Recording ID found: c38a5547-2174-4a0e-8498-55338b2be925
#
# [Progress] Request 172/10000...
#   ✅ Recording ID found: ab8c55bb-f946-4808-ba8c-d6034dd288c7
#
# [Progress] Request 173/10000...
#   ✅ Recording ID found: d24acc9e-fec0-464e-8d72-7596c043530d
#
# [Progress] Request 174/10000...
#   ✅ Recording ID found: 496daa53-13bd-4f10-bad9-1a7fae13dc4a
#
# [Progress] Request 175/10000...
#   ✅ Recording ID found: 74123215-872a-466d-9ac0-1d6a1f4f3829
#
# [Progress] Request 176/10000...
#   ✅ Recording ID found: ac85f504-bcc9-48fd-a189-ce711c2684b1
#
# [Progress] Request 177/10000...
#   ✅ Recording ID found: 9c06a4c6-fbea-4f77-b183-22442ca13b3a
#
# [Progress] Request 178/10000...
#   ✅ Recording ID found: a437126a-c469-4f6e-8cbd-c8e7bcf400ce
#
# [Progress] Request 179/10000...
#   ✅ Recording ID found: f99db99e-7c48-4219-b16e-ab7d98ae9472
#
# [Progress] Request 180/10000...
#   ✅ Recording ID found: 70f75a26-717c-468f-9fc5-6cedf2d8ae4b
#
# [Progress] Request 181/10000...
#   ✅ Recording ID found: bf575993-59fc-4827-9de9-15a728708a9e
#
# [Progress] Request 182/10000...
#   ✅ Recording ID found: 546edae4-a28a-480a-ace2-5203af68c7fd
#
# [Progress] Request 183/10000...
#   ⚠️ Not Recording ID found for: algunas bestias - pablo neruda
#
# [Progress] Request 184/10000...
#   ⚠️ Not Recording ID found for: piedra de sol - octavio paz
#
# [Progress] Request 185/10000...
#   ⚠️ Not Recording ID found for: amnecia - alfaromio
#
# [Progress] Request 186/10000...
#   ⚠️ Not Recording ID found for: esperando la cita - safio
#
# [Progress] Request 187/10000...
#   ⚠️ Not Recording ID found for: eres mi todo - safio
#
# [Progress] Request 188/10000...
#   ⚠️ Not Recording ID found for: confuciones - safio
#
# [Progress] Request 189/10000...
#   ⚠️ Not Recording ID found for: masacre a combate - pika (esp)
#
# [Progress] Request 190/10000...
#   ⚠️ Not Recording ID found for: crack - jey vargas
#
# [Progress] Request 191/10000...
#   ✅ Recording ID found: 0730f4ea-01da-40ca-bea0-6f109a7a1f25
#
# [Progress] Request 192/10000...
#   ⚠️ Not Recording ID found for: piensa bien - bigdoze
#
# [Progress] Request 193/10000...
#   ⚠️ Not Recording ID found for: donde estas - bigdoze
#
# [Progress] Request 194/10000...
#   ✅ Recording ID found: a05fe6c9-c915-461f-a844-b74775b98a86
#
# [Progress] Request 195/10000...
#   ✅ Recording ID found: 72e67dc9-e936-492c-8d0b-672e04e93134
#
# [Progress] Request 196/10000...
#   ⚠️ Not Recording ID found for: una experiencia de vida - safio
#
# [Progress] Request 197/10000...
#   ✅ Recording ID found: a76306f2-448e-4db2-8cf4-0a483f6f43ec
#
# [Progress] Request 198/10000...
#   ⚠️ Not Recording ID found for: love again - chino brown
#
# [Progress] Request 199/10000...
#   ⚠️ Not Recording ID found for: la muerta - pablo neruda
#
# [Progress] Request 200/10000...
#   ⚠️ Not Recording ID found for: oda al tomate - pablo neruda
#
# [Progress] Request 201/10000...
#   ⚠️ Not Recording ID found for: no digas adios - ezley
#
# [Progress] Request 202/10000...
#   ⚠️ Not Recording ID found for: rico por siempre - arcngel
#
# [Progress] Request 203/10000...
#   ⚠️ Not Recording ID found for: tan solo unos segundos - mono ek
#
# [Progress] Request 204/10000...
#   ⚠️ Not Recording ID found for: no saben quien soy - mono ek
#
# [Progress] Request 205/10000...
#   ⚠️ Not Recording ID found for: calle 13 - latinoamérica traduction française - genius traductions franaises
#
# [Progress] Request 206/10000...
#   ⚠️ Not Recording ID found for: el fin del mundo - vicente lopez
#
# [Progress] Request 207/10000...
#   ⚠️ Not Recording ID found for: the unfaithful housewife - federico garca lorca
#
# [Progress] Request 208/10000...
#   ⚠️ Not Recording ID found for: tu que te crees - bigdoze
#
# [Progress] Request 209/10000...
#   ⚠️ Not Recording ID found for: poesia - pablo neruda
#
# [Progress] Request 210/10000...
#   ✅ Recording ID found: a47b7f55-3a0c-4a95-b5a0-ae503ecceb3a
#
# [Progress] Request 211/10000...
#   ⚠️ Not Recording ID found for: soneto xvii - pablo neruda
#
# [Progress] Request 212/10000...
#   ⚠️ Not Recording ID found for: the fickle one - pablo neruda
#
# [Progress] Request 213/10000...
#   ⚠️ Not Recording ID found for: the insect - pablo neruda
#
# [Progress] Request 214/10000...
#   ⚠️ Not Recording ID found for: leaving home spanish version - t.a.n.r.
#
# [Progress] Request 215/10000...
#   ⚠️ Not Recording ID found for: con lv pvnv - ciarci
#
# [Progress] Request 216/10000...
#   ✅ Recording ID found: 3a0be45b-85cc-4134-a2f5-0c5fe5ded77f
#
# [Progress] Request 217/10000...
#   ⚠️ Not Recording ID found for: los fantasmas - planeta mente
#
# [Progress] Request 218/10000...
#   ⚠️ Not Recording ID found for: la televisión - planeta mente
#
# [Progress] Request 219/10000...
#   ✅ Recording ID found: 0eb011c5-7699-4486-86d1-8b5df5858201
#
# [Progress] Request 220/10000...
#   ⚠️ Not Recording ID found for: muévete make a move - cypress hill
#
# [Progress] Request 221/10000...
#   ⚠️ Not Recording ID found for: yo quiero fumar i wanna get high - cypress hill
#
# [Progress] Request 222/10000...
#   ✅ Recording ID found: 31146c3f-946b-46bb-8b62-6cb8d237d4a4
#
# [Progress] Request 223/10000...
#   ✅ Recording ID found: e215f7f2-520b-49c3-aa96-bf4f6ab63106
#
# [Progress] Request 224/10000...
#   ✅ Recording ID found: 1e963bed-89f2-4662-8932-07a192dfcc8c
#
# [Progress] Request 225/10000...
#   ⚠️ Not Recording ID found for: ilusiones illusions - cypress hill
#
# [Progress] Request 226/10000...
#   ⚠️ Not Recording ID found for: tú no ajaunta checkmate - cypress hill
#
# [Progress] Request 227/10000...
#   ✅ Recording ID found: 61a327d5-dd0f-4698-9904-cee3b7807bde
#
# [Progress] Request 228/10000...
#   ⚠️ Not Recording ID found for: en otro sistema solar - j. parker
#
# [Progress] Request 229/10000...
#   ⚠️ Not Recording ID found for: el rey y yo - los ngeles negros
#
# [Progress] Request 230/10000...
#   ⚠️ Not Recording ID found for: lowrider spanish version - cypress hill
#
# [Progress] Request 231/10000...
#   ⚠️ Not Recording ID found for: cocaina - j john
#
# [Progress] Request 232/10000...
#   ⚠️ Not Recording ID found for: el mandamás - mc/ dc
#
# [Progress] Request 233/10000...
#   ⚠️ Not Recording ID found for: bello monte - mc/ dc
#
# [Progress] Request 234/10000...
#   ⚠️ Not Recording ID found for: minutos finales - mc/ dc
#
# [Progress] Request 235/10000...
#   ⚠️ Not Recording ID found for: cara a caracas - mc/ dc
#
# [Progress] Request 236/10000...
#   ✅ Recording ID found: 505b031a-2dfe-45c9-a55a-3ca84a785d44
#
# [Progress] Request 237/10000...
#   ✅ Recording ID found: e7e2760c-504b-4b11-9a1f-ae57f074e235
#
# [Progress] Request 238/10000...
#   ⚠️ Not Recording ID found for: work like chávez - rebel diaz
#
# [Progress] Request 239/10000...
#   ⚠️ Not Recording ID found for: quizás no - c-kan
#
# [Progress] Request 240/10000...
#   ✅ Recording ID found: 7077af3f-6040-4a0b-bd5f-f84957115fe6
#
# [Progress] Request 241/10000...
#   ⚠️ Not Recording ID found for: dulce locura - la horeja de van gogh
#
# [Progress] Request 242/10000...
#   ⚠️ Not Recording ID found for: esperando la cita remix - marius l.
#
# [Progress] Request 243/10000...
#   ⚠️ Not Recording ID found for: antes solias - arcngel
#
# [Progress] Request 244/10000...
#   ✅ Recording ID found: cac8d0a8-a4f7-4cab-a485-ffae6d8387cd
#
# [Progress] Request 245/10000...
#   ✅ Recording ID found: e982187c-8e52-444f-9112-993ad404189e
#
# [Progress] Request 246/10000...
#   ✅ Recording ID found: 0e5df0ce-57b6-4a68-a1f2-f9fc213ecf0c
#
# [Progress] Request 247/10000...
#   ✅ Recording ID found: ce54d729-1463-44ae-9a3b-e5f9cad91c93
#
# [Progress] Request 248/10000...
#   ⚠️ Not Recording ID found for: lucho contra perderte - mc cobra
#
# [Progress] Request 249/10000...
#   ⚠️ Not Recording ID found for: movimiento - nardavid
#
# [Progress] Request 250/10000...
#   ⚠️ Not Recording ID found for: night riders - wearavenue
#
# [Progress] Request 251/10000...
#   ✅ Recording ID found: 92874463-9eb4-4e73-98ca-db4f2e04096c
#
# [Progress] Request 252/10000...
#   ✅ Recording ID found: 9c6964fb-d550-4c9b-8958-e423056c1a5e
#
# [Progress] Request 253/10000...
#   ✅ Recording ID found: d2b566e1-5216-40af-a77e-f54189a45f4e
#
# [Progress] Request 254/10000...
#   ⚠️ Not Recording ID found for: embotellado - c-kan
#
# [Progress] Request 255/10000...
#   ✅ Recording ID found: 8e491007-776c-4db8-a78c-61afedd9ed95
#
# [Progress] Request 256/10000...
#   ⚠️ Not Recording ID found for: no es culpa mía - bonus track - daddy yankee
#
# [Progress] Request 257/10000...
#   ✅ Recording ID found: 3f01e797-6fb1-4254-9e3b-0ce4ed55577e
#
# [Progress] Request 258/10000...
#   ✅ Recording ID found: 7bb532f0-2c3f-4a90-9e91-6467d8683d5c
#
# [Progress] Request 259/10000...
#   ✅ Recording ID found: 1f55c7ae-83f9-4a06-a44e-d9cdb1e5a1a4
#
# [Progress] Request 260/10000...
#   ⚠️ Not Recording ID found for: rap perdido - haris dogg
#
# [Progress] Request 261/10000...
#   ⚠️ Not Recording ID found for: geometria sagrada - mighty kalipssus
#
# [Progress] Request 262/10000...
#   ✅ Recording ID found: 45861f1c-076c-489a-8d0e-b74f6c768652
#
# [Progress] Request 263/10000...
#   ✅ Recording ID found: 92cd7be5-f71b-4f0c-bc76-da8bdab8bc97
#
# [Progress] Request 264/10000...
#   ✅ Recording ID found: 5e24535d-8599-46be-a4a2-88816ee6cbda
#
# [Progress] Request 265/10000...
#   ✅ Recording ID found: 3db005cc-2c12-472c-8d23-e393213a08b9
#
# [Progress] Request 266/10000...
#   ✅ Recording ID found: 651d5af2-dcfe-4273-b593-9588fcf85ede
#
# [Progress] Request 267/10000...
#   ✅ Recording ID found: a8d8dd09-89bc-4a66-8a3a-5deea5ac9a59
#
# [Progress] Request 268/10000...
#   ✅ Recording ID found: eed8f350-76c7-47ce-9a9e-92bf9c39b73e
#
# [Progress] Request 269/10000...
#   ⚠️ Not Recording ID found for: supreme elohim - mighty kalipssus
#
# [Progress] Request 270/10000...
#   ⚠️ Not Recording ID found for: la soledad de américa latina - gabriel garca mrquez
#
# [Progress] Request 271/10000...
#   ⚠️ Not Recording ID found for: prólogo a versos sencillos - jos mart
#
# [Progress] Request 272/10000...
#   ⚠️ Not Recording ID found for: los cisnes - rubn daro
#
# [Progress] Request 273/10000...
#   ⚠️ Not Recording ID found for: canción de otoño en primavera - rubn daro
#
# [Progress] Request 274/10000...
#   ⚠️ Not Recording ID found for: lo fatal - rubn daro
#
# [Progress] Request 275/10000...
#   ⚠️ Not Recording ID found for: lix - csar vallejo
#
# [Progress] Request 276/10000...
#   ⚠️ Not Recording ID found for: lxxvi - csar vallejo
#
# [Progress] Request 277/10000...
#   ✅ Recording ID found: ff34d8ce-e04a-45b3-a619-d1d55e9f66f6
#
# [Progress] Request 278/10000...
#   ⚠️ Not Recording ID found for: a julia de burgos - julia d burgos
#
# [Progress] Request 279/10000...
#   ⚠️ Not Recording ID found for: pentacromía - julia de burgos
#
# [Progress] Request 280/10000...
#   ⚠️ Not Recording ID found for: zero - daniel fernndez 0058
#
# [Progress] Request 281/10000...
#   ⚠️ Not Recording ID found for: nada - julia de burgos
#
# [Progress] Request 282/10000...
#   ⚠️ Not Recording ID found for: poema para mi muerte - julia de burgos
#
# [Progress] Request 283/10000...
#   ⚠️ Not Recording ID found for: pan - gabriela mistral
#
# [Progress] Request 284/10000...
#   ⚠️ Not Recording ID found for: país de la ausencia - gabriela mistral
#
# [Progress] Request 285/10000...
#   ⚠️ Not Recording ID found for: cosas - gabriela mistral
#
# [Progress] Request 286/10000...
#   ⚠️ Not Recording ID found for: la otra - gabriela mistral
#
# [Progress] Request 287/10000...
#   ✅ Recording ID found: 4a0a4a22-202f-4260-ace8-2135cb193eb3
#
# [Progress] Request 288/10000...
#   ⚠️ Not Recording ID found for: uno contra 20 mcs - toteking
#
# [Progress] Request 289/10000...
#   ⚠️ Not Recording ID found for: no pueden conmigo - lapiz conciente
#
# [Progress] Request 290/10000...
#   ⚠️ Not Recording ID found for: tenemos droga - cookin bananas
#
# [Progress] Request 291/10000...
#   ✅ Recording ID found: 89205000-8dcd-45e0-a0e0-0a41b49cb362
#
# [Progress] Request 292/10000...
#   ✅ Recording ID found: f0a51446-986a-473a-bfbf-190098d5e76a
#
# [Progress] Request 293/10000...
#   ✅ Recording ID found: 88bd008d-b2f4-4341-977e-382f529f9e20
#
# [Progress] Request 294/10000...
#   ⚠️ Not Recording ID found for: todo el mundo lo sabe - slo los solo
#
# [Progress] Request 295/10000...
#   ⚠️ Not Recording ID found for: termitas - freshmakers
#
# [Progress] Request 296/10000...
#   ⚠️ Not Recording ID found for: suave - freshmakers
#
# [Progress] Request 297/10000...
#   ✅ Recording ID found: f6225a55-b386-4bc4-a1bd-8c8bb0fec492
#
# [Progress] Request 298/10000...
#   ⚠️ Not Recording ID found for: 2040: tener cuidado america - balake
#
# [Progress] Request 299/10000...
#   ⚠️ Not Recording ID found for: jackpot remix - dub g
#
# [Progress] Request 300/10000...
#   ⚠️ Not Recording ID found for: si yo fuera un chico - beyonc
#
# [Progress] Request 301/10000...
#   ⚠️ Not Recording ID found for: contigo hasta el final - el sueo de morfeo
#
# [Progress] Request 302/10000...
#   ✅ Recording ID found: 16b91c6b-b5a7-46e7-b8d6-f60b11744fc9
#
# [Progress] Request 303/10000...
#   ✅ Recording ID found: ba6d78ef-efe6-43d7-b6a7-922e5e2fb1f4
#
# [Progress] Request 304/10000...
#   ⚠️ Not Recording ID found for: l4t2p lookin for the perfect punchline - noult
#
# [Progress] Request 305/10000...
#   ✅ Recording ID found: 4fd7682b-f268-433a-a26c-303d8a07909f
#
# [Progress] Request 306/10000...
#   ✅ Recording ID found: eae99fab-ef25-4ba8-a94e-8268e6482adf
#
# [Progress] Request 307/10000...
#   ⚠️ Not Recording ID found for: héroe - toteking y shotta
#
# [Progress] Request 308/10000...
#   ✅ Recording ID found: b9d8534e-93f8-42ef-a53f-4a3dc2bab3df
#
# [Progress] Request 309/10000...
#   ✅ Recording ID found: 2fdfba25-8b01-484e-adbd-7d7db299e09a
#
# [Progress] Request 310/10000...
#   ✅ Recording ID found: 61a9ff18-5f6f-476b-8884-05f89e231dde
#
# [Progress] Request 311/10000...
#   ⚠️ Not Recording ID found for: crisis así no llega para comer - frank t
#
# [Progress] Request 312/10000...
#   ⚠️ Not Recording ID found for: de palo me lo pongo - frank t
#
# [Progress] Request 313/10000...
#   ✅ Recording ID found: 9ca37ece-3eed-432e-b539-586e2800aea2
#
# [Progress] Request 314/10000...
#   ✅ Recording ID found: a46cf146-2c05-493a-9c45-3ed4e43961b8
#
# [Progress] Request 315/10000...
#   ✅ Recording ID found: 810486ec-627f-4ee4-af74-24f57bc0d8c5
#
# [Progress] Request 316/10000...
#   ✅ Recording ID found: dd4a6435-8429-479c-98f6-9821a16f9a5b
#
# [Progress] Request 317/10000...
#   ✅ Recording ID found: 387be423-d08c-4e26-aee6-ef4e6d10195a
#
# [Progress] Request 318/10000...
#   ✅ Recording ID found: b8a895de-de32-469e-94b1-3cfbcb74a609
#
# [Progress] Request 319/10000...
#   ⚠️ Not Recording ID found for: on  on - heavy roots
#
# [Progress] Request 320/10000...
#   ✅ Recording ID found: e27dab2d-1f2c-4bc6-a46e-5b0cbe44e0a6
#
# [Progress] Request 321/10000...
#   ✅ Recording ID found: e77c1492-5df8-4224-ae0d-97dfc31bb7f9
#
# [Progress] Request 322/10000...
#   ✅ Recording ID found: 9a6b9238-3bca-46c2-b414-25886e18eae4
#
# [Progress] Request 323/10000...
#   ✅ Recording ID found: 592425e9-33b9-4344-b364-e7193a91a544
#
# [Progress] Request 324/10000...
#   ✅ Recording ID found: 8e52045e-fff2-4757-b22a-56938a133923
#
# [Progress] Request 325/10000...
#   ✅ Recording ID found: f1c1e452-27f9-4e5f-b702-ce7568e64bc1
#
# [Progress] Request 326/10000...
#   ✅ Recording ID found: d00e1b9c-68b2-4faf-bf42-71de2897424c
#
# [Progress] Request 327/10000...
#   ✅ Recording ID found: 83d93b79-0cf5-4e94-bd7a-2c16f95a68c2
#
# [Progress] Request 328/10000...
#   ⚠️ Not Recording ID found for: soy jesse james - j. parker
#
# [Progress] Request 329/10000...
#   ⚠️ Not Recording ID found for: ouh - j. parker
#
# [Progress] Request 330/10000...
#   ⚠️ Not Recording ID found for: ¿quién es peor de los dos? - j. parker
#
# [Progress] Request 331/10000...
#   ⚠️ Not Recording ID found for: lo he vuelto a hacer - j. parker
#
# [Progress] Request 332/10000...
#   ⚠️ Not Recording ID found for: ¿qué más da? - j. parker
#
# [Progress] Request 333/10000...
#   ⚠️ Not Recording ID found for: ahí voy otra vez - j. parker
#
# [Progress] Request 334/10000...
#   ⚠️ Not Recording ID found for: me puedo perder - j. parker
#
# [Progress] Request 335/10000...
#   ⚠️ Not Recording ID found for: mucho que ganar - j. parker
#
# [Progress] Request 336/10000...
#   ⚠️ Not Recording ID found for: mú$ica - j. parker
#
# [Progress] Request 337/10000...
#   ⚠️ Not Recording ID found for: los raperos enfadados de mi edad - j. parker
#
# [Progress] Request 338/10000...
#   ⚠️ Not Recording ID found for: todos van a peor - j. parker
#
# [Progress] Request 339/10000...
#   ⚠️ Not Recording ID found for: aunque pueda parecer que no - j. parker
#
# [Progress] Request 340/10000...
#   ✅ Recording ID found: 2a79dede-31aa-4280-94b9-bb13488a8e08
#
# [Progress] Request 341/10000...
#   ✅ Recording ID found: d7e00aee-980c-4127-95af-f5f183d8c6e3
#
# [Progress] Request 342/10000...
#   ✅ Recording ID found: 4ea324f0-70f9-4d99-99eb-162a6da5f2af
#
# [Progress] Request 343/10000...
#   ✅ Recording ID found: 9e8d9bbf-21e8-4eb5-98f9-0dd4d129d26b
#
# [Progress] Request 344/10000...
#   ✅ Recording ID found: 2f1d2740-ab22-4768-8cc0-befbf34d87f2
#
# [Progress] Request 345/10000...
#   ✅ Recording ID found: d9d00d14-dbec-4650-9875-429cfec00f05
#
# [Progress] Request 346/10000...
#   ✅ Recording ID found: 5000e4ae-1a26-42f0-ae13-93c09b8158ff
#
# [Progress] Request 347/10000...
#   ✅ Recording ID found: bc14f74a-48aa-450d-8c78-45a05d3f6ee8
#
# [Progress] Request 348/10000...
#   ✅ Recording ID found: b0ffbd2f-704f-4d88-80fd-c8e7549fa0f6
#
# [Progress] Request 349/10000...
#   ✅ Recording ID found: 62f1d542-0803-45c8-a41d-6f865d445e57
#
# [Progress] Request 350/10000...
#   ✅ Recording ID found: 552d736c-2e69-4e23-a9ef-95571f279d77
#
# [Progress] Request 351/10000...
#   ✅ Recording ID found: 6a9ce9ff-3581-46ab-a7e6-4589997730f7
#
# [Progress] Request 352/10000...
#   ⚠️ Not Recording ID found for: mc escandaloso xpósito - escandaloso xpsito
#
# [Progress] Request 353/10000...
#   ⚠️ Not Recording ID found for: vamos otra vez - hermanos hermticos
#
# [Progress] Request 354/10000...
#   ⚠️ Not Recording ID found for: leyendas legales - hermanos hermticos
#
# [Progress] Request 355/10000...
#   ✅ Recording ID found: ef903ce7-ac92-4567-b756-c766c38db793
#
# [Progress] Request 356/10000...
#   ⚠️ Not Recording ID found for: sonámbulos - hablando en plata squad
#
# [Progress] Request 357/10000...
#   ✅ Recording ID found: 1c5cb364-3b1d-4067-8e87-197748951c04
#
# [Progress] Request 358/10000...
#   ✅ Recording ID found: 4402e3f7-3597-4c8e-b012-af33cf13d543
#
# [Progress] Request 359/10000...
#   ✅ Recording ID found: 675a0351-bbd5-4ae2-ae81-01c57cf9eed9
#
# [Progress] Request 360/10000...
#   ✅ Recording ID found: d463035b-d64e-4107-b4e2-c52be13c419c
#
# [Progress] Request 361/10000...
#   ✅ Recording ID found: 78d5feaf-2b7a-4c06-b717-4bb7449a7723
#
# [Progress] Request 362/10000...
#   ✅ Recording ID found: 877f6c71-e5cb-44f1-aaa9-c59fb7aa1539
#
# [Progress] Request 363/10000...
#   ✅ Recording ID found: 0c2b2517-7c68-4b20-8e7d-f6123e3d071d
#
# [Progress] Request 364/10000...
#   ✅ Recording ID found: 696abd57-31b0-4b73-8580-c7da6561a14b
#
# [Progress] Request 365/10000...
#   ✅ Recording ID found: 8966e8da-ac1c-4cc4-9564-0084ad231be6
#
# [Progress] Request 366/10000...
#   ✅ Recording ID found: e7aebc73-321f-4489-aa63-43ca861c8029
#
# [Progress] Request 367/10000...
#   ✅ Recording ID found: 68def9f9-15ed-4eeb-b12a-c3b9535b5719
#
# [Progress] Request 368/10000...
#   ✅ Recording ID found: 782d4bdd-b404-465d-a8e2-80ba97a39210
#
# [Progress] Request 369/10000...
#   ✅ Recording ID found: 402bd0a6-fb5a-46fc-8a6d-e7aca97eca68
#
# [Progress] Request 370/10000...
#   ✅ Recording ID found: e65b4486-8262-4645-a31a-293465795845
#
# [Progress] Request 371/10000...
#   ✅ Recording ID found: ed1a3027-0a47-44b3-8ab3-53e9deee4f16
#
# [Progress] Request 372/10000...
#   ✅ Recording ID found: a42cf2d4-4cab-42f0-aebb-b21f6370c7cc
#
# [Progress] Request 373/10000...
#   ✅ Recording ID found: 0c6c33c6-2d42-4e74-a30d-d9ea915b6090
#
# [Progress] Request 374/10000...
#   ✅ Recording ID found: d414cd09-a1f8-4555-82ae-ecba079b4745
#
# [Progress] Request 375/10000...
#   ✅ Recording ID found: 60d65d5b-f787-4c1c-ae37-ea921dc85a79
#
# [Progress] Request 376/10000...
#   ✅ Recording ID found: 5647befb-4e60-4c17-b2e7-633910a804d2
#
# [Progress] Request 377/10000...
#   ✅ Recording ID found: b77d3042-167c-414c-920f-e1d657e93964
#
# [Progress] Request 378/10000...
#   ✅ Recording ID found: 85dc646e-5459-4ac0-ab5a-6b2f787350e2
#
# [Progress] Request 379/10000...
#   ✅ Recording ID found: 8feb2875-e7e9-445e-92a8-686d32044022
#
# [Progress] Request 380/10000...
#   ⚠️ Not Recording ID found for: efímero - cabal (esp)
#
# [Progress] Request 381/10000...
#   ✅ Recording ID found: 4c46a118-a3e3-46e8-afc8-b00dcbac333d
#
# [Progress] Request 382/10000...
#   ✅ Recording ID found: 63c4eb77-9629-4d8a-ae1b-b942445b9892
#
# [Progress] Request 383/10000...
#   ✅ Recording ID found: 542a94e0-0cf8-4e4d-988a-3fcd3fa808c9
#
# [Progress] Request 384/10000...
#   ✅ Recording ID found: 9e40a86d-8a6e-4e68-8d00-71b584cc856d
#
# [Progress] Request 385/10000...
#   ✅ Recording ID found: c484267e-84a2-4898-89e1-2a8f0b2ca8e6
#
# [Progress] Request 386/10000...
#   ⚠️ Not Recording ID found for: lo que hago - cabal (esp)
#
# [Progress] Request 387/10000...
#   ✅ Recording ID found: 5e411691-b84e-4e3d-9969-a754ea8ef47b
#
# [Progress] Request 388/10000...
#   ✅ Recording ID found: bcc12c11-055e-43d8-9ffe-7cfee87ad622
#
# [Progress] Request 389/10000...
#   ✅ Recording ID found: 494fac16-e5a9-4fd7-9104-01067a62b9f0
#
# [Progress] Request 390/10000...
#   ✅ Recording ID found: 8b4d48b1-0b73-404f-ad68-e8c1705c164a
#
# [Progress] Request 391/10000...
#   ✅ Recording ID found: fb3a01d9-18be-47e5-804f-9bbf507fe908
#
# [Progress] Request 392/10000...
#   ✅ Recording ID found: b93531a9-5cc2-4ed3-842f-5e4728e5a337
#
# [Progress] Request 393/10000...
#   ✅ Recording ID found: 832b37d4-a2b8-47f6-be01-71c388283b23
#
# [Progress] Request 394/10000...
#   ✅ Recording ID found: 28f78113-481c-4743-9471-c2b05ffe7849
#
# [Progress] Request 395/10000...
#   ✅ Recording ID found: 72032abb-18f7-4a65-a9f1-60168d07bb93
#
# [Progress] Request 396/10000...
#   ✅ Recording ID found: 55830afc-570f-4507-b161-f64f10507d71
#
# [Progress] Request 397/10000...
#   ✅ Recording ID found: 2d624b55-5b1c-490a-a27a-cc2532b578ac
#
# [Progress] Request 398/10000...
#   ✅ Recording ID found: 07e2047a-e464-4f5e-bdde-6be50e22efa4
#
# [Progress] Request 399/10000...
#   ✅ Recording ID found: a91ac67c-e5d6-443c-a890-5e346f8a60db
#
# [Progress] Request 400/10000...
#   ✅ Recording ID found: 27837255-999f-47b0-b9f2-c9df7e1cd28f
#
# [Progress] Request 401/10000...
#   ✅ Recording ID found: 342857ca-3a38-4128-b7e6-cb02882bc0c1
#
# [Progress] Request 402/10000...
#   ✅ Recording ID found: 2c604f89-1727-41e2-9839-4cb1adc7550d
#
# [Progress] Request 403/10000...
#   ✅ Recording ID found: 7960fbde-d691-4c3d-809a-f474e5f3f7ed
#
# [Progress] Request 404/10000...
#   ⚠️ Not Recording ID found for: deudas con el karma - freshmakers
#
# [Progress] Request 405/10000...
#   ⚠️ Not Recording ID found for: intro - freshmakers
#
# [Progress] Request 406/10000...
#   ⚠️ Not Recording ID found for: demasiado corazón - freshmakers
#
# [Progress] Request 407/10000...
#   ⚠️ Not Recording ID found for: no me vale - freshmakers
#
# [Progress] Request 408/10000...
#   ⚠️ Not Recording ID found for: complicaciones - freshmakers
#
# [Progress] Request 409/10000...
#   ⚠️ Not Recording ID found for: pasar mi tiempo conmigo - freshmakers
#
# [Progress] Request 410/10000...
#   ⚠️ Not Recording ID found for: lo tenemos - freshmakers
#
# [Progress] Request 411/10000...
#   ⚠️ Not Recording ID found for: pull out - freshmakers
#
# [Progress] Request 412/10000...
#   ⚠️ Not Recording ID found for: recuérdame que nunca me olvide - freshmakers
#
# [Progress] Request 413/10000...
#   ⚠️ Not Recording ID found for: azul claro - freshmakers
#
# [Progress] Request 414/10000...
#   ⚠️ Not Recording ID found for: el artefuckto - el artefuckto
#
# [Progress] Request 415/10000...
#   ✅ Recording ID found: c28a635e-b5cb-483d-ad40-c562792da6ff
#
# [Progress] Request 416/10000...
#   ⚠️ Not Recording ID found for: me acuerdo - el artefuckto
#
# [Progress] Request 417/10000...
#   ⚠️ Not Recording ID found for: experiencia - el artefuckto
#
# [Progress] Request 418/10000...
#   ✅ Recording ID found: e40e5e03-1889-4c8b-912d-1ac83c9d2cd4
#
# [Progress] Request 419/10000...
#   ⚠️ Not Recording ID found for: a dios le ipod - juanes
#
# [Progress] Request 420/10000...
#   ✅ Recording ID found: 0764fb57-7163-496b-b076-00ca903f01c5
#
# [Progress] Request 421/10000...
#   ✅ Recording ID found: e23f3717-7adb-4eca-828d-124cbf50c214
#
# [Progress] Request 422/10000...
#   ⚠️ Not Recording ID found for: hasta el próximo - lgrimas de sangre
#
# [Progress] Request 423/10000...
#   ⚠️ Not Recording ID found for: uve de - j. parker
#
# [Progress] Request 424/10000...
#   ⚠️ Not Recording ID found for: viñetas - j. parker
#
# [Progress] Request 425/10000...
#   ⚠️ Not Recording ID found for: big gang bang - j. parker
#
# [Progress] Request 426/10000...
#   ⚠️ Not Recording ID found for: entre tú y yo - j. parker
#
# [Progress] Request 427/10000...
#   ⚠️ Not Recording ID found for: y tú ¿qué? - j. parker
#
# [Progress] Request 428/10000...
#   ⚠️ Not Recording ID found for: malas caras - j. parker
#
# [Progress] Request 429/10000...
#   ⚠️ Not Recording ID found for: cierra la puerta - j. parker
#
# [Progress] Request 430/10000...
#   ⚠️ Not Recording ID found for: sin estribillo - j. parker
#
# [Progress] Request 431/10000...
#   ⚠️ Not Recording ID found for: ponle hielo - j. parker
#
# [Progress] Request 432/10000...
#   ⚠️ Not Recording ID found for: ese soy yo - j. parker
#
# [Progress] Request 433/10000...
#   ⚠️ Not Recording ID found for: enciendan las luces - j. parker
#
# [Progress] Request 434/10000...
#   ⚠️ Not Recording ID found for: otro día - j. parker
#
# [Progress] Request 435/10000...
#   ⚠️ Not Recording ID found for: really down - j. parker
#
# [Progress] Request 436/10000...
#   ⚠️ Not Recording ID found for: otro día - bekas
#
# [Progress] Request 437/10000...
#   ⚠️ Not Recording ID found for: blanco y negro - bekas
#
# [Progress] Request 438/10000...
#   ✅ Recording ID found: 5f43f5b8-568b-47cd-8e71-426ec35ba05a
#
# [Progress] Request 439/10000...
#   ✅ Recording ID found: a7159625-a85b-430b-bd20-29efc3deb208
#
# [Progress] Request 440/10000...
#   ⚠️ Not Recording ID found for: logro desbloqueado - noult
#
# [Progress] Request 441/10000...
#   ⚠️ Not Recording ID found for: preparado para el duelo - noult
#
# [Progress] Request 442/10000...
#   ✅ Recording ID found: 9a02991d-4f5b-4dca-8ee6-1a864aa5ecba
#
# [Progress] Request 443/10000...
#   ⚠️ Not Recording ID found for: dame1minuto noult - aisho
#
# [Progress] Request 444/10000...
#   ✅ Recording ID found: 3e24ebaf-0f81-441c-8a7f-ad0c163c1e78
#
# [Progress] Request 445/10000...
#   ✅ Recording ID found: 9d4b3ec9-e596-4308-8ba7-c83cd245f9b0
#
# [Progress] Request 446/10000...
#   ✅ Recording ID found: 8ef3a957-959e-4a6a-bd2a-b4b78999a743
#
# [Progress] Request 447/10000...
#   ✅ Recording ID found: c035e24d-938d-429b-b98b-987b3cdf7a09
#
# [Progress] Request 448/10000...
#   ✅ Recording ID found: dc75295c-e5a3-4eff-be39-424ac5a14b3a
#
# [Progress] Request 449/10000...
#   ✅ Recording ID found: 7473746b-d47c-494a-b1e9-ede1a631d151
#
# [Progress] Request 450/10000...
#   ✅ Recording ID found: a9140ab8-b3c8-4f56-ae37-de32498d1061
#
# [Progress] Request 451/10000...
#   ✅ Recording ID found: 28b2bbe2-571d-473d-8fb3-87f39f308bb7
#
# [Progress] Request 452/10000...
#   ✅ Recording ID found: 872509d5-18b8-45b4-9cea-b6320d78260b
#
# [Progress] Request 453/10000...
#   ✅ Recording ID found: c345afc8-747d-4b31-9e62-f163bf2d8fa5
#
# [Progress] Request 454/10000...
#   ✅ Recording ID found: f68fae82-bc1d-4b59-bc45-354b6b96ea09
#
# [Progress] Request 455/10000...
#   ✅ Recording ID found: ddfad838-1e23-4278-ab80-cd0ee3f8b411
#
# [Progress] Request 456/10000...
#   ✅ Recording ID found: a981b91c-b1de-4471-af82-556b5b69e699
#
# [Progress] Request 457/10000...
#   ✅ Recording ID found: fdfbc3b1-01d3-4a94-8ddd-f74d7fa61f44
#
# [Progress] Request 458/10000...
#   ✅ Recording ID found: 29ffdf80-b2cd-4252-a535-ff9181dabfcb
#
# [Progress] Request 459/10000...
#   ⚠️ Not Recording ID found for: mi estilo de vida - ejo
#
# [Progress] Request 460/10000...
#   ⚠️ Not Recording ID found for: madrid - cpv
#
# [Progress] Request 461/10000...
#   ⚠️ Not Recording ID found for: zona bruta - cpv
#
# [Progress] Request 462/10000...
#   ⚠️ Not Recording ID found for: extramaunción - cpv
#
# [Progress] Request 463/10000...
#   ⚠️ Not Recording ID found for: raggamanada - cpv
#
# [Progress] Request 464/10000...
#   ✅ Recording ID found: 17ca2eac-3b59-4a54-af2c-c7eb53671a3d
#
# [Progress] Request 465/10000...
#   ✅ Recording ID found: ea3c9b44-ff10-458e-a372-f1889c66d84e
#
# [Progress] Request 466/10000...
#   ✅ Recording ID found: cc80fd54-2c91-4e6d-9fed-3ac13a0933b8
#
# [Progress] Request 467/10000...
#   ✅ Recording ID found: 736268fd-a21e-436e-a2c3-efcee7410f4f
#
# [Progress] Request 468/10000...
#   ✅ Recording ID found: 1a27ace1-b017-4c28-8542-b49ef877333e
#
# [Progress] Request 469/10000...
#   ✅ Recording ID found: 3ad111c9-fa6b-491d-bafc-a494ca723343
#
# [Progress] Request 470/10000...
#   ⚠️ Not Recording ID found for: cristal / asfalto - h roto
#
# [Progress] Request 471/10000...
#   ✅ Recording ID found: 1d13a872-a211-4a0a-9b08-8e6dd28ffe57
#
# [Progress] Request 472/10000...
#   ✅ Recording ID found: 62a195a4-b667-4efe-a395-93bea833d182
#
# [Progress] Request 473/10000...
#   ✅ Recording ID found: 23933b6f-b2e8-4140-8948-b238c5feac06
#
# [Progress] Request 474/10000...
#   ⚠️ Not Recording ID found for: soy... poeta - znit
#
# [Progress] Request 475/10000...
#   ⚠️ Not Recording ID found for: zenitown - znit
#
# [Progress] Request 476/10000...
#   ⚠️ Not Recording ID found for: torre de babel - znit
#
# [Progress] Request 477/10000...
#   ✅ Recording ID found: a2caad31-2131-465f-9e51-8302e68504bd
#
# [Progress] Request 478/10000...
#   ⚠️ Not Recording ID found for: ella - znit
#
# [Progress] Request 479/10000...
#   ⚠️ Not Recording ID found for: v.o.s. - znit
#
# [Progress] Request 480/10000...
#   ⚠️ Not Recording ID found for: ingeniería alemana - znit
#
# [Progress] Request 481/10000...
#   ⚠️ Not Recording ID found for: se quedó solo - znit
#
# [Progress] Request 482/10000...
#   ⚠️ Not Recording ID found for: vaffanculo - znit
#
# [Progress] Request 483/10000...
#   ⚠️ Not Recording ID found for: enjambre - isaac aka mr elstico
#
# [Progress] Request 484/10000...
#   ⚠️ Not Recording ID found for: tu refugio - znit
#
# [Progress] Request 485/10000...
#   ⚠️ Not Recording ID found for: es por vosotros - znit
#
# [Progress] Request 486/10000...
#   ⚠️ Not Recording ID found for: es por vos-outro - znit
#
# [Progress] Request 487/10000...
#   ✅ Recording ID found: 2dcdc219-fca8-4108-8ecf-320d185ae828
#
# [Progress] Request 488/10000...
#   ✅ Recording ID found: d69c2d7c-5642-45eb-be9b-6c0cec451f95
#
# [Progress] Request 489/10000...
#   ✅ Recording ID found: d5fa194d-bada-4a4d-93df-58db2926d493
#
# [Progress] Request 490/10000...
#   ✅ Recording ID found: d927fe1d-6b3c-49d3-8a5b-4ee2c0374edb
#
# [Progress] Request 491/10000...
#   ✅ Recording ID found: f0cd587c-6406-40b9-9954-ed3b7adb6488
#
# [Progress] Request 492/10000...
#   ✅ Recording ID found: f08bc1ba-136d-46e1-8aab-4ff2e00ae40e
#
# [Progress] Request 493/10000...
#   ⚠️ Not Recording ID found for: lespirit de lescalier - rayden
#
# [Progress] Request 494/10000...
#   ✅ Recording ID found: 3c1ca4e5-0c9a-444c-bba6-85745e3e444c
#
# [Progress] Request 495/10000...
#   ✅ Recording ID found: 76e6f9ef-3bac-49ac-b97d-18b1dedb5b9a
#
# [Progress] Request 496/10000...
#   ✅ Recording ID found: 2c4107df-e9b4-48a1-b1a3-8d0b4a7b8341
#
# [Progress] Request 497/10000...
#   ✅ Recording ID found: 3908da68-632b-45a3-b790-80fc0db76634
#
# [Progress] Request 498/10000...
#   ✅ Recording ID found: 8205d52f-be39-49b0-9843-8a552495211c
#
# [Progress] Request 499/10000...
#   ✅ Recording ID found: 99ce1b49-4735-408a-abf9-7207af239b37
#
# [Progress] Request 500/10000...
#   ✅ Recording ID found: 7010d22b-095b-4390-9c70-978d80aa6d14
#
# [Progress] Request 501/10000...
#   ✅ Recording ID found: 2694a5fe-0d18-4746-bc32-e538531ce01b
#
# [Progress] Request 502/10000...
#   ✅ Recording ID found: c9d887ed-c346-46ad-8a7a-cdefa1b969d7
#
# [Progress] Request 503/10000...
#   ✅ Recording ID found: 3ee38488-68cb-44d5-997e-6d93d7ac097e
#
# [Progress] Request 504/10000...
#   ✅ Recording ID found: fb3a424e-08e3-4aaf-b6d3-2d65db991967
#
# [Progress] Request 505/10000...
#   ✅ Recording ID found: 3a3db26d-6e5a-4c30-8e1c-a299de6b22f7
#
# [Progress] Request 506/10000...
#   ✅ Recording ID found: 4959adfe-5e4e-4623-af4c-dc69023384cd
#
# [Progress] Request 507/10000...
#   ✅ Recording ID found: 9bda0799-0273-4875-aa34-2141fba946f7
#
# [Progress] Request 508/10000...
#   ✅ Recording ID found: 3193c4f2-85bf-4d24-a663-c9479fe0a809
#
# [Progress] Request 509/10000...
#   ✅ Recording ID found: 612ea1e8-7375-419f-9e57-7d8dafc56a04
#
# [Progress] Request 510/10000...
#   ✅ Recording ID found: 5b82b3bc-f07b-4dac-98c5-e2d642b2c250
#
# [Progress] Request 511/10000...
# ...
#   ✅ Recording ID found: 0a415dc1-97be-4cb2-a7ad-e9883a1ae109
#
# [Progress] Request 9838/10000...
#   ⚠️ Not Recording ID found for: paloma herida - alejandra guzmn
#
# [Progress] Request 9839/10000...
#   ✅ Recording ID found: 4551e851-ff8a-4885-b449-ef7b051a77c0
#
# [Progress] Request 9840/10000...
#   ✅ Recording ID found: a47d68b2-e000-434b-a711-c970bd1f3b47
#
# [Progress] Request 9841/10000...
#   ✅ Recording ID found: b3bedb02-40cf-459e-af6a-902159324c49
#
# [Progress] Request 9842/10000...
#   ✅ Recording ID found: b0a5f771-49a6-4750-b2e8-45f6c4b84ba7
#
# [Progress] Request 9843/10000...
#   ✅ Recording ID found: ef3e986a-e7f5-4878-8487-2c8a0839bc6b
#
# [Progress] Request 9844/10000...
#   ✅ Recording ID found: 7270eeaa-593a-4435-a6a9-63527e7504e1
#
# [Progress] Request 9845/10000...
#   ✅ Recording ID found: 3367ee4f-8ae7-4179-b171-d2d4cd0f1d12
#
# [Progress] Request 9846/10000...
#   ✅ Recording ID found: 92a403ba-9b1e-4be5-be38-d6a1431d9af7
#
# [Progress] Request 9847/10000...
#   ✅ Recording ID found: 02ed4fd2-95ed-46cc-98c0-17959d0e9f85
#
# [Progress] Request 9848/10000...
#   ✅ Recording ID found: dc81347a-8dc3-4bac-bf68-455a88387ae5
#
# [Progress] Request 9849/10000...
#   ✅ Recording ID found: 3372b486-3cff-4ef4-b53d-296d129589de
#
# [Progress] Request 9850/10000...
#   ✅ Recording ID found: 9564405c-8db0-46a6-9f7d-759eb9711547
#
# [Progress] Request 9851/10000...
#   ⚠️ Not Recording ID found for: la plaga - alejandra guzmn
#
# [Progress] Request 9852/10000...
#   ✅ Recording ID found: c0c0cad6-0405-4f89-af67-3113f0addd48
#
# [Progress] Request 9853/10000...
#   ✅ Recording ID found: f87010a9-1987-4e19-ac01-fc218fe56d3c
#
# [Progress] Request 9854/10000...
#   ⚠️ Not Recording ID found for: hasta el final - alejandra guzmn
#
# [Progress] Request 9855/10000...
#   ✅ Recording ID found: 4bc5a59a-28ec-4700-bd11-d6a120649ed4
#
# [Progress] Request 9856/10000...
#   ✅ Recording ID found: 7a131f95-5642-4417-8185-bfa0324b47de
#
# [Progress] Request 9857/10000...
#   ⚠️ Not Recording ID found for: sin límites - alejandra guzmn
#
# [Progress] Request 9858/10000...
#   ✅ Recording ID found: d20a2c7d-4228-4c56-a288-01e2353457b0
#
# [Progress] Request 9859/10000...
#   ✅ Recording ID found: 1dae4ee8-b8f2-41c4-856b-b30c8b7c35d7
#
# [Progress] Request 9860/10000...
#   ✅ Recording ID found: 8dd957ab-77cb-4216-ba5e-a500158f6dd2
#
# [Progress] Request 9861/10000...
#   ✅ Recording ID found: 88d52eeb-38c6-46af-aee8-0253b8d112c2
#
# [Progress] Request 9862/10000...
#   ✅ Recording ID found: 25d8fb34-0855-4ae7-b210-0436375c979e
#
# [Progress] Request 9863/10000...
#   ✅ Recording ID found: 75681372-ddad-43b0-a6be-067485e08fab
#
# [Progress] Request 9864/10000...
#   ⚠️ Not Recording ID found for: diana - alejandra guzmn
#
# [Progress] Request 9865/10000...
#   ✅ Recording ID found: 1fe4c8c8-0b3c-43e6-861b-ef37eb4a5a2e
#
# [Progress] Request 9866/10000...
#   ✅ Recording ID found: 052dd509-5f58-4d78-b16c-7c6ff5959511
#
# [Progress] Request 9867/10000...
#   ✅ Recording ID found: 01c72fee-f9e3-4ff8-a726-6a33f321918d
#
# [Progress] Request 9868/10000...
#   ✅ Recording ID found: dd3d35cb-b9b7-4d37-8367-0781030518ab
#
# [Progress] Request 9869/10000...
#   ⚠️ Not Recording ID found for: me perdí en tu cuerpo - alejandra guzmn
#
# [Progress] Request 9870/10000...
#   ✅ Recording ID found: aacc8b45-8c94-42b4-9872-e35cd2407948
#
# [Progress] Request 9871/10000...
#   ⚠️ Not Recording ID found for: set acústico en vivo la guzmán - alejandra guzmn
#
# [Progress] Request 9872/10000...
#   ✅ Recording ID found: 29b0af79-ebd5-4e94-8f1f-2de78a6dfc70
#
# [Progress] Request 9873/10000...
#   ✅ Recording ID found: 2927b15b-aac3-4949-9876-cad61338d30f
#
# [Progress] Request 9874/10000...
#   ✅ Recording ID found: 3873534d-e31e-4274-803e-a023fef2f00d
#
# [Progress] Request 9875/10000...
#   ✅ Recording ID found: b2cd2714-3677-4ebf-b8e5-d8ac98e650dc
#
# [Progress] Request 9876/10000...
#   ✅ Recording ID found: 79389607-0304-45c6-b283-8d8c74f61898
#
# [Progress] Request 9877/10000...
#   ✅ Recording ID found: 97627184-d843-46c0-a3f3-8267cc6b7346
#
# [Progress] Request 9878/10000...
#   ⚠️ Not Recording ID found for: si no te has ido vete - alejandra guzmn
#
# [Progress] Request 9879/10000...
#   ✅ Recording ID found: 4e77bb32-22f2-4196-9169-4e6656a03b6a
#
# [Progress] Request 9880/10000...
#   ✅ Recording ID found: 216ac0c5-4440-4094-8753-780b8298796b
#
# [Progress] Request 9881/10000...
#   ⚠️ Not Recording ID found for: morir de amor - alejandra guzmn
#
# [Progress] Request 9882/10000...
#   ✅ Recording ID found: 5caeba7b-4cb3-47df-804f-11e04534bb59
#
# [Progress] Request 9883/10000...
#   ✅ Recording ID found: 83ad88b7-a40b-416f-a4bd-7ddd34c2cede
#
# [Progress] Request 9884/10000...
#   ✅ Recording ID found: 3fcca23a-aa85-4938-96a5-c6ba11389581
#
# [Progress] Request 9885/10000...
#   ✅ Recording ID found: 8b0bd126-078f-4a08-8ff9-01ec304b2cc8
#
# [Progress] Request 9886/10000...
#   ✅ Recording ID found: 521ac60d-6f05-4c14-90c9-1f3cdf890c0c
#
# [Progress] Request 9887/10000...
#   ✅ Recording ID found: e219500d-ebed-45b5-ac00-b6fde968145d
#
# [Progress] Request 9888/10000...
#   ✅ Recording ID found: 6375677c-c81e-488d-89d3-61e153da8ed5
#
# [Progress] Request 9889/10000...
#   ⚠️ Not Recording ID found for: hay punkies en moscú - alejandra guzmn
#
# [Progress] Request 9890/10000...
#   ✅ Recording ID found: d58274c6-4da4-4eb8-8812-4c8137fdf8b2
#
# [Progress] Request 9891/10000...
#   ✅ Recording ID found: 12b3c1e9-f573-4f21-a656-4b934dea7f7a
#
# [Progress] Request 9892/10000...
#   ✅ Recording ID found: 6305ee6e-2536-41a7-b6e8-f7559b6667c1
#
# [Progress] Request 9893/10000...
#   ✅ Recording ID found: 123d2548-26f0-44be-a6b0-bf4f4d3f25fa
#
# [Progress] Request 9894/10000...
#   ✅ Recording ID found: f8dc486e-87c4-4d1b-8958-fca0ed9a7029
#
# [Progress] Request 9895/10000...
#   ⚠️ Not Recording ID found for: un grito en la noche - alejandra guzmn
#
# [Progress] Request 9896/10000...
#   ✅ Recording ID found: 55f4c1e1-ddf9-4dfe-bba9-989c6fa4ea96
#
# [Progress] Request 9897/10000...
#   ⚠️ Not Recording ID found for: siénteme a tu lado - alejandra guzmn
#
# [Progress] Request 9898/10000...
#   ⚠️ Not Recording ID found for: llama por favor - alejandra guzmn
#
# [Progress] Request 9899/10000...
#   ✅ Recording ID found: 08bd0520-6374-43c7-89e8-899891406ed0
#
# [Progress] Request 9900/10000...
#   ✅ Recording ID found: 9c687987-0f46-4cb4-aab1-dae59f77d8f8
#
# [Progress] Request 9901/10000...
#   ⚠️ Not Recording ID found for: soy solo un secreto - alejandra guzmn
#
# [Progress] Request 9902/10000...
#   ✅ Recording ID found: 60c7275b-304d-481d-ab7d-d8cde1210622
#
# [Progress] Request 9903/10000...
#   ✅ Recording ID found: b5dd86ca-34cd-4e7e-9ec8-b46aea112090
#
# [Progress] Request 9904/10000...
#   ✅ Recording ID found: 7deba918-0a5f-43aa-95d1-dd6aa9454809
#
# [Progress] Request 9905/10000...
#   ✅ Recording ID found: 45a184e1-b2c3-4439-bf12-eb71dc8a6de4
#
# [Progress] Request 9906/10000...
#   ✅ Recording ID found: 71bd87ef-7c28-4cd7-a7ef-e59e3ade14d9
#
# [Progress] Request 9907/10000...
#   ✅ Recording ID found: 13be4f0d-4225-4ae3-afe6-035ee90a6510
#
# [Progress] Request 9908/10000...
#   ✅ Recording ID found: a360b8d6-0029-45bf-bf0b-570620987967
#
# [Progress] Request 9909/10000...
#   ✅ Recording ID found: ab8d717d-db15-4587-9bab-7d4d4312a4c0
#
# [Progress] Request 9910/10000...
#   ✅ Recording ID found: 9035d005-5f44-4529-a6bb-a2ef7b789159
#
# [Progress] Request 9911/10000...
#   ✅ Recording ID found: 22925230-842a-4a5f-a207-f0f05a035373
#
# [Progress] Request 9912/10000...
#   ✅ Recording ID found: 1747a0c3-57bb-48f4-a7eb-1dff39c57128
#
# [Progress] Request 9913/10000...
#   ✅ Recording ID found: 403e413b-df75-4b6d-8336-c06d1bbc2a40
#
# [Progress] Request 9914/10000...
#   ✅ Recording ID found: 508c279d-f255-4676-82f1-51677ada955f
#
# [Progress] Request 9915/10000...
#   ✅ Recording ID found: bdb33cb7-fa8a-4b2a-9f54-155398dd2c9c
#
# [Progress] Request 9916/10000...
#   ✅ Recording ID found: ccada288-66c4-4471-8705-7676d16fec08
#
# [Progress] Request 9917/10000...
#   ✅ Recording ID found: e6e024b1-b87e-4422-afdf-108560576a00
#
# [Progress] Request 9918/10000...
#   ✅ Recording ID found: 45eb6688-9a57-45a3-a6ad-ba16a4f47654
#
# [Progress] Request 9919/10000...
#   ⚠️ Not Recording ID found for: reina de corazones - alejandra guzmn
#
# [Progress] Request 9920/10000...
#   ✅ Recording ID found: 257f2196-ebad-494e-b5c2-f1b543942adc
#
# [Progress] Request 9921/10000...
#   ✅ Recording ID found: 82782557-4da0-45af-b76e-44a99901cc4d
#
# [Progress] Request 9922/10000...
#   ✅ Recording ID found: 07b6576e-283a-4397-b52c-a22fdd99cfb3
#
# [Progress] Request 9923/10000...
#   ✅ Recording ID found: 4c287995-f843-44a4-9706-967f11fd5e71
#
# [Progress] Request 9924/10000...
#   ✅ Recording ID found: d0238c39-0008-46ea-aa2c-a43aa6ed338f
#
# [Progress] Request 9925/10000...
#   ⚠️ Not Recording ID found for: satisfacción - alejandra guzmn
#
# [Progress] Request 9926/10000...
#   ✅ Recording ID found: 17935243-74e9-47b5-ab14-861dd94c98b9
#
# [Progress] Request 9927/10000...
#   ✅ Recording ID found: c3f17cd0-9a77-4469-a004-4547ba52a471
#
# [Progress] Request 9928/10000...
#   ✅ Recording ID found: 8bd58b1a-189d-4279-9101-4bd1dbbe5eec
#
# [Progress] Request 9929/10000...
#   ⚠️ Not Recording ID found for: no seas cruel - alejandra guzmn
#
# [Progress] Request 9930/10000...
#   ⚠️ Not Recording ID found for: vuelvo a besar - alejandra guzmn
#
# [Progress] Request 9931/10000...
#   ✅ Recording ID found: 7a8c56d0-d9f6-4f07-b994-f37cb181ba80
#
# [Progress] Request 9932/10000...
#   ✅ Recording ID found: 5fe05a07-75b6-466f-8282-907cf50ee21e
#
# [Progress] Request 9933/10000...
#   ✅ Recording ID found: 6ec0ee68-ac31-4364-bd1e-57bc3ab16a40
#
# [Progress] Request 9934/10000...
#   ✅ Recording ID found: b442eaa7-8007-43b2-a4fe-99e794ff5f1e
#
# [Progress] Request 9935/10000...
#   ✅ Recording ID found: dc76ba60-33cd-4a16-98c2-d4006bd2e0b6
#
# [Progress] Request 9936/10000...
#   ⚠️ Not Recording ID found for: pablo - alejandra guzmn
#
# [Progress] Request 9937/10000...
#   ✅ Recording ID found: dd17b954-6131-4d97-8f22-7b8d9ba110b9
#
# [Progress] Request 9938/10000...
#   ✅ Recording ID found: a79b5d04-474a-405b-9d56-6c8d66ca0df1
#
# [Progress] Request 9939/10000...
#   ✅ Recording ID found: a2c1b077-d420-446d-9302-2277a3623dd8
#
# [Progress] Request 9940/10000...
#   ✅ Recording ID found: e966e5fa-8c5b-4efe-8738-2af61e8c1adc
#
# [Progress] Request 9941/10000...
#   ⚠️ Not Recording ID found for: no voy a esperar - alejandra guzmn
#
# [Progress] Request 9942/10000...
#   ✅ Recording ID found: fbb8e90f-c92c-4ce4-9aea-d0b5c64716c6
#
# [Progress] Request 9943/10000...
#   ✅ Recording ID found: e0a2be62-58db-49aa-b46f-a632d15dbddb
#
# [Progress] Request 9944/10000...
#   ⚠️ Not Recording ID found for: soy tuya mi amor - alejandra guzmn
#
# [Progress] Request 9945/10000...
#   ✅ Recording ID found: 14c8b0b6-204f-487d-a4e1-21f5adf7ceab
#
# [Progress] Request 9946/10000...
#   ✅ Recording ID found: 8f4e6686-e67f-49d0-a4bf-cbfc05640b08
#
# [Progress] Request 9947/10000...
#   ⚠️ Not Recording ID found for: libre - alejandra guzmn
#
# [Progress] Request 9948/10000...
#   ✅ Recording ID found: db7cdde9-fb9d-4331-9b84-e937af7e79f3
#
# [Progress] Request 9949/10000...
#   ⚠️ Not Recording ID found for: bello imposible - alejandra guzmn
#
# [Progress] Request 9950/10000...
#   ⚠️ Not Recording ID found for: recordarás - alejandra guzmn
#
# [Progress] Request 9951/10000...
#   ✅ Recording ID found: 5810c39c-51c0-4143-98db-9ae06c4460d9
#
# [Progress] Request 9952/10000...
#   ✅ Recording ID found: cb62da20-5928-445a-962a-5005277e393a
#
# [Progress] Request 9953/10000...
#   ⚠️ Not Recording ID found for: quema despacio - alejandra guzmn
#
# [Progress] Request 9954/10000...
#   ✅ Recording ID found: 0c0fe3a6-df7b-47df-a40c-186f56effbc7
#
# [Progress] Request 9955/10000...
#   ⚠️ Not Recording ID found for: supersexitada - alejandra guzmn
#
# [Progress] Request 9956/10000...
#   ⚠️ Not Recording ID found for: quiero armar un escándalo - alejandra guzmn
#
# [Progress] Request 9957/10000...
#   ✅ Recording ID found: e0f21312-69a9-4ccb-bbdb-091b96c2bd6d
#
# [Progress] Request 9958/10000...
#   ✅ Recording ID found: 124b506e-a9ce-4dfb-96d9-780effe68e86
#
# [Progress] Request 9959/10000...
#   ✅ Recording ID found: 55d7911b-18ac-47a7-9607-792a42a51256
#
# [Progress] Request 9960/10000...
#   ✅ Recording ID found: 810ab78c-8e99-40e7-b55f-0ed3360de134
#
# [Progress] Request 9961/10000...
#   ⚠️ Not Recording ID found for: quiero ser - alejandra guzmn
#
# [Progress] Request 9962/10000...
#   ✅ Recording ID found: 4927008a-6adf-4925-baab-4e1983b31529
#
# [Progress] Request 9963/10000...
#   ✅ Recording ID found: d9e00d15-e65c-469b-b0d2-2655996f1ec0
#
# [Progress] Request 9964/10000...
#   ✅ Recording ID found: 0b6460e1-ea96-4d61-a201-4ae949ca77e6
#
# [Progress] Request 9965/10000...
#   ✅ Recording ID found: 99b502a4-effc-4b1d-ad1b-e897580b2242
#
# [Progress] Request 9966/10000...
#   ✅ Recording ID found: d83e82ff-5822-43cf-80eb-9f99a5f983eb
#
# [Progress] Request 9967/10000...
#   ✅ Recording ID found: 02a4256f-1e2d-4c47-b168-985393e2f3dd
#
# [Progress] Request 9968/10000...
#   ⚠️ Not Recording ID found for: buena onda - alejandra guzmn
#
# [Progress] Request 9969/10000...
#   ✅ Recording ID found: 8316ee72-a4fd-4a8b-a653-b227f4f49c0b
#
# [Progress] Request 9970/10000...
#   ✅ Recording ID found: 4e2933aa-d197-4198-9c6b-0f77f97595d2
#
# [Progress] Request 9971/10000...
#   ⚠️ Not Recording ID found for: tocarte - alejandra guzmn
#
# [Progress] Request 9972/10000...
#   ✅ Recording ID found: 1e5c90c4-56de-40c8-b91c-47b695bb6547
#
# [Progress] Request 9973/10000...
#   ✅ Recording ID found: 057c8769-2649-4cd7-9728-891227bb2664
#
# [Progress] Request 9974/10000...
#   ⚠️ Not Recording ID found for: rezo - alejandra guzmn
#
# [Progress] Request 9975/10000...
#   ✅ Recording ID found: ad3b7005-1d33-40da-838f-dbdf2c725a14
#
# [Progress] Request 9976/10000...
#   ✅ Recording ID found: 5d9ba509-4dbe-4a2e-a010-996502508479
#
# [Progress] Request 9977/10000...
#   ⚠️ Not Recording ID found for: te esperaba - alejandra guzmn
#
# [Progress] Request 9978/10000...
#   ⚠️ Not Recording ID found for: tengo derecho a estar mal - alejandra guzmn
#
# [Progress] Request 9979/10000...
#   ⚠️ Not Recording ID found for: sálvame - alejandra guzmn
#
# [Progress] Request 9980/10000...
#   ✅ Recording ID found: 07074b01-738e-46c6-8b90-9fc77c705836
#
# [Progress] Request 9981/10000...
#   ⚠️ Not Recording ID found for: mírala míralo - alejandra guzmn
#
# [Progress] Request 9982/10000...
#   ✅ Recording ID found: a37729b3-e8b0-4824-a3b2-f81d712fa72c
#
# [Progress] Request 9983/10000...
#   ✅ Recording ID found: f1b57c3a-2021-4f5f-abac-fe4f6fa7a513
#
# [Progress] Request 9984/10000...
#   ⚠️ Not Recording ID found for: tirando piedras - alejandra guzmn
#
# [Progress] Request 9985/10000...
#   ⚠️ Not Recording ID found for: soy - alejandra guzmn
#
# [Progress] Request 9986/10000...
#   ✅ Recording ID found: 0c9cd841-a2ea-48a1-8a0c-c9d653374d57
#
# [Progress] Request 9987/10000...
#   ⚠️ Not Recording ID found for: toda la mitad - alejandra guzmn
#
# [Progress] Request 9988/10000...
#   ✅ Recording ID found: 585fac71-9248-4665-a0bd-7bcd3d0e25fd
#
# [Progress] Request 9989/10000...
#   ✅ Recording ID found: a2214e88-4c3c-4ddf-9da4-7c50dd909f93
#
# [Progress] Request 9990/10000...
#   ⚠️ Not Recording ID found for: vagabundo corazón - alejandra guzmn
#
# [Progress] Request 9991/10000...
#   ⚠️ Not Recording ID found for: bellísima - alejandra guzmn
#
# [Progress] Request 9992/10000...
#   ✅ Recording ID found: 6ff9c310-bae0-476a-87ad-33b45d03171b
#
# [Progress] Request 9993/10000...
#   ⚠️ Not Recording ID found for: todo - alejandra guzmn
#
# [Progress] Request 9994/10000...
#   ✅ Recording ID found: fd8f722a-102b-42cb-9f4d-cf2b823f080d
#
# [Progress] Request 9995/10000...
#   ✅ Recording ID found: ef3914b2-c0d4-459e-a49b-f8655964f80b
#
# [Progress] Request 9996/10000...
#   ⚠️ Not Recording ID found for: amor en suspenso crocodile tears - alejandra guzmn
#
# [Progress] Request 9997/10000...
#   ✅ Recording ID found: 36dce0b1-7aef-437e-984b-9200e56f8768
#
# [Progress] Request 9998/10000...
#   ✅ Recording ID found: a1d94d37-9c88-43c0-b43c-887a3d12518e
#
# [Progress] Request 9999/10000...
#   ✅ Recording ID found: 382b46ae-75d7-481a-b758-31f75f6466e9
#
# [Progress] Request 10000/10000...
#   ⚠️ Not Recording ID found for: buscando tu amor - alejandra guzmn
#
# Processing complete. Results saved in:
#  - Found: C:\Users\solan\Downloads\get_data_from_songs\data\raw\1_nuevos_ids_encontrados.csv.temp
#  - Not Found: C:\Users\solan\Downloads\get_data_from_songs\data\1ids_no_encontrados.csv.temp

# %% [markdown]
# Una vez termine o se corte la ejecución, los datos de los que se ha encontrado recording_id estarán en [nuevos_ids_encontrados.csv.temp](../data/raw/nuevos_ids_encontrados.csv.temp) y los que no se encuentren, en [ids_no_encontrados.csv.temp](../data/raw/ids_no_encontrados.csv.temp).
#
# En caso de que se vuelva a ejecutar la función, si los archivos ya existen y contienen datos, estos no se sobreescriben, sino que se añaden al final. Para evitar duplicados y ahorrar tiempo, lo ideal es eliminar los datos que ya están en [nuevos_ids_encontrados.csv.temp](../data/raw/nuevos_ids_encontrados.csv.temp) y [ids_no_encontrados.csv.temp](../data/raw/ids_no_encontrados.csv.temp) del dataset a procesar. Para ello tenemos la función [remove_existing_records()](eliminar-de-un-dataset-que-existen-en-otro.ipynb)
